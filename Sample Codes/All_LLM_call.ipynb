# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### OpenAI Call

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.2",
    temperature=0.7,
    input="Write a one-sentence bedtime story about a unicorn.",
)

# print(response)
print(response.output_text)
# Out:
# As the moon sprinkled silver light over the quiet meadow, a gentle unicorn named Luma tucked the sleepy flowers in with her shimmering tail and wished every child a safe, cozy dream.

# %%
import os
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4.1")
ans = model.invoke("Explain the theory of relativity in simple terms.")
print(ans)
print("="*100)
print(ans.content)
# Out:
# content='Sure! The theory of relativity is actually two theories by Albert Einstein:\n\n### 1. **Special Relativity**\n- This theory says that the laws of physics are the same for everyone, no matter how fast they’re moving (as long as they’re not speeding up or slowing down).\n- The speed of light is always the same for everyone, no matter how fast they’re moving.\n- Weird things happen when things move really fast (close to the speed of light):  \n    - Time slows down for moving objects ("time dilation").\n    - Things get shorter in the direction they’re moving ("length contraction").\n    - Mass increases as you go faster.\n- Famous formula: **E = mc²** (energy and mass are connected).\n\n### 2. **General Relativity**\n- This theory is about gravity.\n- Before Einstein, gravity was thought of as a force (Newton’s idea).\n- Einstein said: Gravity is actually what happens when massive objects (like the Earth) bend space and time around them.\n    - Imagine space and time as a trampoline. If you put a bowling ball on it, the trampoline curves. If you roll a marble near it, it’ll move toward the bowling ball because of the curve. That’s what gravity is!\n- This explains things that Newton’s theory couldn’t, like why planets’ orbits change a little over time or the bending of light around massive stars.\n\n**In summary:**  \nSpecial relativity is about how speed affects time and space; general relativity is about how mass and energy bend space and time, creating what we feel as gravity.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 324, 'prompt_tokens': 17, 'total_tokens': 341, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_1a2c4a5ede', 'finish_reason': 'stop', 'logprobs': None} id='run--531143cd-8a39-402c-a953-0813a9bdef02-0' usage_metadata={'input_tokens': 17, 'output_tokens': 324, 'total_tokens': 341, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# ====================================================================================================
# Sure! The theory of relativity is actually two theories by Albert Einstein:
#
# ### 1. **Special Relativity**
# - This theory says that the laws of physics are the same for everyone, no matter how fast they’re moving (as long as they’re not speeding up or slowing down).
# - The speed of light is always the same for everyone, no matter how fast they’re moving.
# - Weird things happen when things move really fast (close to the speed of light):
#     - Time slows down for moving objects ("time dilation").
#     - Things get shorter in the direction they’re moving ("length contraction").
#     - Mass increases as you go faster.
# - Famous formula: **E = mc²** (energy and mass are connected).
#
# ### 2. **General Relativity**
# - This theory is about gravity.
# - Before Einstein, gravity was thought of as a force (Newton’s idea).
# - Einstein said: Gravity is actually what happens when massive objects (like the Earth) bend space and time around them.
#     - Imagine space and time as a trampoline. If you put a bowling ball on it, the trampoline curves. If you roll a marble near it, it’ll move toward the bowling ball because of the curve. That’s what gravity is!
# - This explains things that Newton’s theory couldn’t, like why planets’ orbits change a little over time or the bending of light around massive stars.
#
# **In summary:**
# Special relativity is about how speed affects time and space; general relativity is about how mass and energy bend space and time, creating what we feel as gravity.

# %% [markdown]
# ### Gemini Call

# %%
from google import genai
import os
api_key = os.environ["GEMINI_API_KEY"]
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI analyzes massive amounts of data to find patterns and make predictions.

# %% [markdown]
# ### Ollama Call

# %%
from ollama import chat

response = chat(
    model='gpt-oss',
    messages=[{'role': 'user', 'content': 'Hello!'}],
)
print(response.message.content)
# Out:
# Hello! How can I help you today?

# %% [markdown]
# ### GROQ API CALL

# %%
import os

from groq import Groq
from dotenv import load_dotenv  
load_dotenv()
client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models are crucial in natural language processing (NLP) due to their ability to quickly and efficiently process and generate human-like language. The importance of fast language models can be seen in several areas:
#
# 1. **Real-time Applications**: Fast language models enable real-time applications such as chatbots, virtual assistants, and voice-activated interfaces. These models can respond quickly to user input, providing a seamless and interactive experience.
# 2. **Scalability**: Fast language models can handle large volumes of data and process multiple requests simultaneously, making them ideal for large-scale applications such as language translation, text summarization, and sentiment analysis.
# 3. **Low Latency**: Fast language models minimize latency, which is essential for applications that require immediate responses, such as customer service chatbots, voice assistants, and real-time language translation.
# 4. **Improved User Experience**: Fast language models provide a more responsive and interactive user experience, which is critical for applications that require user engagement, such as language learning platforms, writing assistants, and content generation tools.
# 5. **Increased Productivity**: Fast language models can automate tasks such as data entry, document processing, and content generation, freeing up human resources for more strategic and creative tasks.
# 6. **Competitive Advantage**: Companies that adopt fast language models can gain a competitive advantage in the market by providing faster and more efficient language-based services, such as language translation, content generation, and customer support.
# 7. **Edge Computing**: Fast language models are essential for edge computing applications, where data is processed in real-time at the edge of the network, reducing latency and improving overall system performance.
# 8. **Multimodal Interaction**: Fast language models enable multimodal interaction, such as speech, text, and gesture recognition, which is critical for applications like virtual assistants, smart home devices, and autonomous vehicles.
# 9. **Personalization**: Fast language models can personalize user experiences by quickly processing user data and generating tailored responses, recommendations, and content.
# 10. **Research and Development**: Fast language models accelerate research and development in NLP, enabling researchers to explore new ideas, test hypotheses, and develop more sophisticated language models.
#
# To achieve fast language models, researchers and developers employ various techniques, such as:
#
# 1. **Model pruning**: Reducing the complexity of language models by removing unnecessary weights and connections.
# 2. **Knowledge distillation**: Transferring knowledge from large pre-trained models to smaller, faster models.
# 3. **Quantization**: Representing model weights and activations using lower-precision data types to reduce computational requirements.
# 4. **Parallelization**: Distributing computational tasks across multiple processing units, such as GPUs, to speed up processing times.
# 5. **Optimized inference**: Using optimized inference algorithms and frameworks to reduce latency and improve throughput.
#
# By leveraging these techniques, fast language models can be applied to a wide range of applications, from chatbots and virtual assistants to language translation, text summarization, and content generation, revolutionizing the way we interact with language and machines.
